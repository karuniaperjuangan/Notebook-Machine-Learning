# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import tree
np.set_printoptions(precision=3, suppress=False)

# %%
iris = datasets.load_iris( as_frame=True)

# %%
iris.data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(iris.data,iris.target, random_state = 42)

# %%
clf = tree.DecisionTreeClassifier(max_depth =3, random_state = 0)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
plt.figure(figsize=(20,20), facecolor ='w')
tree.plot_tree(clf, feature_names = iris.feature_names, class_names = iris.target_names, filled = True, rounded=True, fontsize=16)
plt.show()

# %%
predict_test = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cf = confusion_matrix(y_test, predict_test, normalize='true')
sns.heatmap(cf, annot=True)
print(cf)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
